# %%
import pandas as pd

# %%
city_df = pd.read_parquet("../003_data/003_merged-data/merged_cms_ballot-measures_by-city.parquet")

# %%
city_vote_df = city_df.dropna(subset=['vote_count'])
# Out:
#       year       county         city provider_number profit_or_nonprofit  \
# 1478  2022  santa clara     san jose           52305          non_profit
# 1479  2022  santa clara     san jose           52305          non_profit
# 1480  2022       orange       orange           52311          non_profit
# 1481  2022       orange       orange           52311          non_profit
# 1482  2022  los angeles  los angeles           52321          non_profit
# ...    ...          ...          ...             ...                 ...
# 6979  2018        kings      hanford          552644              profit
# 6980  2018   sacramento   sacramento           52676          non_profit
# 6981  2018   sacramento   sacramento           52676          non_profit
# 6982  2018       orange       orange           50069          non_profit
# 6983  2018       orange       orange           50069          non_profit
#
#      std_chain_organization ichcahps_data_availability_code  \
# ...
