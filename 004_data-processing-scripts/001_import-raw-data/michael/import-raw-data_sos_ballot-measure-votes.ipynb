# %%
import polars as pl
from datetime import datetime
import pyarrow.parquet as pq

# %%
# URL of the Excel file
url_2022 = "https://elections.cdn.sos.ca.gov/sov/2022-general/ssov/ballot-measures-political-districts.xlsx"

url_2020 = "https://elections.cdn.sos.ca.gov/sov/2020-general/ssov/ballot-measure-all.xlsx"

url_2018 = "https://elections.cdn.sos.ca.gov/sov/2018-general/ssov/ballot-measures-pol-districts.xls"

# Function processing Excel files 
# Returns a combined DataFrame

def process_excel_files(urls_and_years):
    combined_df = pl.DataFrame()
    
    for url, year in urls_and_years:
        # Read the Excel file
        df = pl.read_excel(url)
        
        # Get the first two columns
        # This works because the first two columns are always the county and sub_county
        first_two_cols = df.columns[:2]
        
        # The below code chunk finds columns with "Kidney" or "Dialysis" (yes votes) and their following columns
        # This works because the yes vote/no vote columns appear consecutively in the original data
        
        # Initialize an empty list to store columns related to kidney/dialysis propositions
        kidney_dialysis_cols = []

        # Iterate through all the columns in the DataFrame
        for i, col in enumerate(df.columns):
            # Checking if the current column contains "Kidney" or "Dialysis" in any of its values
            if df[col].str.contains("Kidney|Dialysis").any():
                # Adding matching columns to the list
                kidney_dialysis_cols.extend([
                    col,  # yes vote column
                    df.columns[i+1] if i+1 < len(df.columns) else None  # no vote column
                ])
        
        # Combining all required columns
        selected_cols = first_two_cols + kidney_dialysis_cols
        
        # Select only the required columns
        df_processed = df.select(selected_cols)
        
        # Renaming columns
        new_names = {
            df_processed.columns[0]: "county",
            df_processed.columns[1]: "sub_county"
        }
        for col in df_processed.columns[2:]:
            if "Proposition" in col:
                new_names[col] = "yes"
            else:
                new_names[col] = "no"
        
        df_processed = df_processed.rename(new_names)
        
        # Add the year column
        df_processed = df_processed.with_columns(pl.lit(year).alias("year"))
        
        # Append to the combined DataFrame
        combined_df = pl.concat([combined_df, df_processed])
    
    return combined_df

# URLs and corresponding years
urls_and_years = [
    (url_2022, 2022),
    (url_2020, 2020),
    (url_2018, 2018)
]

# Process all files and store the combined DataFrame as df
df = process_excel_files(urls_and_years)

# Display the first few rows of the combined DataFrame
print("Combined Data:")
print(combined_df.head())

# Displaying some basic information about the combined DataFrame
# This should help with data validation
print("\nDataFrame Info:")
print(f"Shape: {combined_df.shape}")
print(f"Columns: {combined_df.columns}")
print("\nYear distribution:")
print(combined_df.group_by("year").agg(pl.count()).sort("year"))
# Out:
# Combined Data:
# shape: (5, 5)
# ┌────────────────┬───────────────┬─────────────────────┬────────────────────┬──────┐
# │ county         ┆ sub_county    ┆ yes                 ┆ no                 ┆ year │
# │ ---            ┆ ---           ┆ ---                 ┆ ---                ┆ ---  │
# │ str            ┆ str           ┆ str                 ┆ str                ┆ i32  │
# ╞════════════════╪═══════════════╪═════════════════════╪════════════════════╪══════╡
#    ┆ null               ┆ 2022 │ ┆ Regulates Kidney
# │                ┆               ┆ Dialysis Cli…       ┆                    ┆      │
# │ null           ┆ null          ┆ YES                 ┆ NO                 ┆ 2022 │
# │ Alameda County ┆ null          ┆ null                ┆ null               ┆ 2022 │
# │ null           ┆ County Totals ┆ 182697              ┆ 290746             ┆ 2022 │
# │ null           ┆ Percent       ┆ 0.38589017051683094 ┆ 0.6141098294831691 ┆ 2022 │
# └────────────────┴───────────────┴─────────────────────┴────────────────────┴──────┘
#
# DataFrame Info:
# Shape: (4560, 5)
# Columns: ['county', 'sub_county', 'yes', 'no', 'year']
#
# Year distribution:
# shape: (3, 2)
# ┌──────┬───────┐
# │ year ┆ count │
# │ ---  ┆ ---   │
# │ i32  ┆ u32   │
# ╞══════╪═══════╡
# │ 2018 ┆ 1518  │
# │ 2020 ┆ 1517  │
# │ 2022 ┆ 1525  │
# └──────┴───────┘
# /var/folders/29/ysfdqqh96xd2zvnqnqd_8fm80000gn/T/ipykernel_99821/3091877195.py:85: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
#   print(combined_df.group_by("year").agg(pl.count()).sort("year"))

# %%
# Forward filling county names

df = df.with_columns(pl.col("county").forward_fill())

# %%
# Creating a column to identify the geopolitical entity of observations

df = df.with_columns(
    pl.when(pl.col("sub_county") == "Cities")
    .then(pl.lit("city"))
    .when(pl.col("sub_county") == "County Totals")
    .then(pl.lit("city_end"))
    .when(pl.col("sub_county").str.contains("State Senate"))
    .then(pl.lit("state_senate_district"))
    .when(pl.col("sub_county").str.contains("State Assembly"))
    .then(pl.lit("state_assembly_district"))
    .when(pl.col("sub_county").str.contains("Congressional"))
    .then(pl.lit("federal_congressional_district"))
    .when(pl.col("sub_county").str.contains("County Supervisorial"))
    .then(pl.lit("county_supervisorial_district"))
    .otherwise(None)
    .alias("geo_type")
).with_columns(pl.col("geo_type").forward_fill())

df = (df.with_columns(
    pl.col("sub_county").str.extract(r"\d+", 0).alias("sub_county_id"))
) 

# Stripping the "County" suffix from the county names
df = (df.with_columns(
    pl.col("county").str.strip_suffix(" County").alias("county"))
)

# Stripping the "County1" suffix from the county names
# This is necessary because County1 is an erroneous suffix in the original data

df = (df.with_columns(
    pl.col("county").str.strip_suffix(" County1").alias("county"))
)

# %%
df
# Out:
# shape: (4_560, 7)
# ┌─────────┬────────────────┬────────────────┬───────────────┬──────┬───────────────┬───────────────┐
# │ county  ┆ sub_county     ┆ yes            ┆ no            ┆ year ┆ geo_type      ┆ sub_county_id │
# │ ---     ┆ ---            ┆ ---            ┆ ---           ┆ ---  ┆ ---           ┆ ---           │
# │ str     ┆ str            ┆ str            ┆ str           ┆ i32  ┆ str           ┆ str           │
# ╞═════════╪════════════════╪════════════════╪═══════════════╪══════╪═══════════════╪═══════════════╡
# │ null    ┆ null           ┆ Regulates      ┆ null          ┆ 2022 ┆ null          ┆ null          │
# │         ┆                ┆ Kidney
#         ┆               ┆      ┆               ┆               │
# │         ┆                ┆ Dialysis Cli…  ┆               ┆      ┆               ┆               │
# │ null    ┆ null           ┆ YES            ┆ NO            ┆ 2022 ┆ null          ┆ null          │
# │ Alameda ┆ null           ┆ null           ┆ null          ┆ 2022 ┆ null          ┆ null          │
# │ Alameda ┆ County Totals  ┆ 182697         ┆ 290746        ┆ 2022 ┆ city_end      ┆ null          │
# │ Alameda ┆ Percent        ┆ 0.385890170516 ┆ 0.61410982948 ┆ 2022 ┆ city_end      ┆ null          │
# │         ┆                ┆ 83094          ┆ 31691         ┆      ┆               ┆               │
# │ Alameda ┆ County         ┆ 31161          ┆ 65845         ┆ 2022 ┆ county_superv ┆ 1             │
# │         ┆ Supervisorial  ┆                ┆               ┆      ┆ isorial_distr ┆               │
# │         ┆ 1              ┆                ┆               ┆      ┆ ict           ┆               │
# │ Alameda ┆ County         ┆ 28778          ┆ 44258         ┆ 2022 ┆ county_superv ┆ 2             │
# │         ┆ Supervisorial  ┆                ┆               ┆      ┆ isorial_distr ┆               │
# │         ┆ 2              ┆                ┆               ┆      ┆ ict           ┆               │
# │ Alameda ┆ County         ┆ 34338          ┆ 48590         ┆ 2022 ┆ county_superv ┆ 3             │
# │         ┆ Supervisorial  ┆                ┆               ┆      ┆ isorial_distr ┆               │
# │         ┆ 3              ┆                ┆               ┆      ┆ ict           ┆               │
# │ Alameda ┆ County         ┆ 33897          ┆ 60759         ┆ 2022 ┆ county_superv ┆ 4             │
# │         ┆ Supervisorial  ┆                ┆               ┆      ┆ isorial_distr ┆               │
# │         ┆ 4              ┆                ┆               ┆      ┆ ict           ┆               │
# │ Alameda ┆ County         ┆ 54523          ┆ 71294         ┆ 2022 ┆ county_superv ┆ 5             │
# │         ┆ Supervisorial  ┆                ┆               ┆      ┆ isorial_distr ┆               │
# │         ┆ 5              ┆                ┆               ┆      ┆ ict           ┆               │
# │ Alameda ┆ US             ┆ 4465           ┆ 7055          ┆ 2022 ┆ federal_congr ┆ 10            │
# │         ┆ Congressional  ┆                ┆               ┆      ┆ essional_dist ┆               │
# │         ┆ 10             ┆                ┆               ┆      ┆ rict          ┆               │
# │ Alameda ┆ US             ┆ 100680         ┆ 135563        ┆ 2022 ┆ federal_congr ┆ 12            │
# │         ┆ Congressional  ┆                ┆               ┆      ┆ essional_dist ┆               │
# │         ┆ 12             ┆                ┆               ┆      ┆ rict          ┆               │
# │ Alameda ┆ US             ┆ 67996          ┆ 131310        ┆ 2022 ┆ federal_congr ┆ 14            │
# │         ┆ Congressional  ┆                ┆               ┆      ┆ essional_dist ┆               │
# │         ┆ 14             ┆                ┆               ┆      ┆ rict          ┆               │
# │ Alameda ┆ US             ┆ 9556           ┆ 16818         ┆ 2022 ┆ federal_congr ┆ 17            │
# │         ┆ Congressional  ┆                ┆               ┆      ┆ essional_dist ┆               │
# │         ┆ 17             ┆                ┆               ┆      ┆ rict          ┆               │
# │ Alameda ┆ State Senate 5 ┆ 23169          ┆ 56283         ┆ 2022 ┆ state_senate_ ┆ 5             │
# │         ┆                ┆                ┆               ┆      ┆ district      ┆               │
# │ Alameda ┆ State Senate 7 ┆ 93718          ┆ 124902        ┆ 2022 ┆ state_senate_ ┆ 7             │
# │         ┆                ┆                ┆               ┆      ┆ district      ┆               │
# │ Alameda ┆ State Senate 9 ┆ 20989          ┆ 36471         ┆ 2022 ┆ state_senate_ ┆ 9             │
# │         ┆                ┆                ┆               ┆      ┆ district      ┆               │
# │ Alameda ┆ State Senate   ┆ 44821          ┆ 73090         ┆ 2022 ┆ state_senate_ ┆ 10            │
# │         ┆ 10             ┆                ┆               ┆      ┆ district      ┆               │
# │ Alameda ┆ State Assembly ┆ 32876          ┆ 50457         ┆ 2022 ┆ state_assembl ┆ 14            │
# │         ┆ 14             ┆                ┆               ┆      ┆ y_district    ┆               │
# │ Alameda ┆ State Assembly ┆ 18544          ┆ 45874         ┆ 2022 ┆ state_assembl ┆ 16            │
# │         ┆ 16             ┆                ┆               ┆      ┆ y_district    ┆               │
# │ Alameda ┆ State Assembly ┆ 60844          ┆ 74454         ┆ 2022 ┆ state_assembl ┆ 18            │
# │         ┆ 18             ┆                ┆               ┆      ┆ y_district    ┆               │
# │ Alameda ┆ State Assembly ┆ 46517          ┆ 77807         ┆ 2022 ┆ state_assembl ┆ 20            │
# │         ┆ 20             ┆                ┆               ┆      ┆ y_district    ┆               │
# │ Alameda ┆ State Assembly ┆ 23916          ┆ 42154         ┆ 2022 ┆ state_assembl ┆ 24            │
# │         ┆ 24             ┆                ┆               ┆      ┆ y_district    ┆               │
# │ Alameda ┆ State Board of ┆ 182697         ┆ 290746        ┆ 2022 ┆ state_assembl ┆ 2             │
# │         ┆ Equalization 2 ┆                ┆               ┆      ┆ y_district    ┆               │
# │ Alameda ┆ Cities         ┆ null           ┆ null          ┆ 2022 ┆ city          ┆ null          │
# │ …       ┆ …              ┆ …              ┆ …             ┆ …    ┆ …             ┆ …             │
# │ Yolo    ┆ State Assembly ┆ 23223          ┆ 32529         ┆ 2018 ┆ state_assembl ┆ 4             │
# │         ┆ District 4     ┆                ┆               ┆      ┆ y_district    ┆               │
# │ Yolo    ┆ State Assembly ┆ 6238           ┆ 9353          ┆ 2018 ┆ state_assembl ┆ 7             │
# │         ┆ District 7     ┆                ┆               ┆      ┆ y_district    ┆               │
# │ Yolo    ┆ Board of       ┆ 29461          ┆ 41882         ┆ 2018 ┆ state_assembl ┆ 2             │
# │         ┆ Equalization   ┆                ┆               ┆      ┆ y_district    ┆               │
# │         ┆ District…      ┆                ┆               ┆      ┆               ┆               │
# │ Yolo    ┆ Cities         ┆ null           ┆ null          ┆ 2018 ┆ city          ┆ null          │
# │ Yolo    ┆ Davis          ┆ 12662          ┆ 14572         ┆ 2018 ┆ city          ┆ null          │
# │ Yolo    ┆ West           ┆ 6238           ┆ 9353          ┆ 2018 ┆ city          ┆ null          │
# │         ┆ Sacramento     ┆                ┆               ┆      ┆               ┆               │
# │ Yolo    ┆ Winters        ┆ 896            ┆ 1423          ┆ 2018 ┆ city          ┆ null          │
# │ Yolo    ┆ Woodland       ┆ 6863           ┆ 11569         ┆ 2018 ┆ city          ┆ null          │
# │ Yolo    ┆ Unincorporated ┆ 2802           ┆ 4965          ┆ 2018 ┆ city          ┆ null          │
# │         ┆ area of Yolo   ┆                ┆               ┆      ┆               ┆               │
# │         ┆ Co…            ┆                ┆               ┆      ┆               ┆               │
# │ Yuba    ┆ null           ┆ null           ┆ null          ┆ 2018 ┆ city          ┆ null          │
# │ Yuba    ┆ County Totals  ┆ 5967           ┆ 12845         ┆ 2018 ┆ city_end      ┆ null          │
# │ Yuba    ┆ Percent        ┆ 0.317191154582 ┆ 0.68280884541 ┆ 2018 ┆ city_end      ┆ null          │
# │         ┆                ┆ 1816           ┆ 78184         ┆      ┆               ┆               │
# │ Yuba    ┆ Supervisorial  ┆ 996            ┆ 1934          ┆ 2018 ┆ city_end      ┆ 1             │
# │         ┆ District 1     ┆                ┆               ┆      ┆               ┆               │
# │ Yuba    ┆ Supervisorial  ┆ 1020           ┆ 2083          ┆ 2018 ┆ city_end      ┆ 2             │
# │         ┆ District 2     ┆                ┆               ┆      ┆               ┆               │
# │ Yuba    ┆ Supervisorial  ┆ 897            ┆ 1865          ┆ 2018 ┆ city_end      ┆ 3             │
# │         ┆ District 3     ┆                ┆               ┆      ┆               ┆               │
# │ Yuba    ┆ Supervisorial  ┆ 1379           ┆ 2842          ┆ 2018 ┆ city_end      ┆ 4             │
# │         ┆ District 4     ┆                ┆               ┆      ┆               ┆               │
# │ Yuba    ┆ Supervisorial  ┆ 1675           ┆ 4121          ┆ 2018 ┆ city_end      ┆ 5             │
# │         ┆ District 5     ┆                ┆               ┆      ┆               ┆               │
# │ Yuba    ┆ Congressional  ┆ 5967           ┆ 12845         ┆ 2018 ┆ federal_congr ┆ 3             │
# │         ┆ District 3     ┆                ┆               ┆      ┆ essional_dist ┆               │
# │         ┆                ┆                ┆               ┆      ┆ rict          ┆               │
# │ Yuba    ┆ State Senate   ┆ 5967           ┆ 12845         ┆ 2018 ┆ state_senate_ ┆ 4             │
# │         ┆ District 4     ┆                ┆               ┆      ┆ district      ┆               │
# │ Yuba    ┆ State Assembly ┆ 5967           ┆ 12845         ┆ 2018 ┆ state_assembl ┆ 3             │
# │         ┆ District 3     ┆                ┆               ┆      ┆ y_district    ┆               │
# │ Yuba    ┆ Board of       ┆ 5967           ┆ 12845         ┆ 2018 ┆ state_assembl ┆ 1             │
# │         ┆ Equalization   ┆                ┆               ┆      ┆ y_district    ┆               │
# │         ┆ District…      ┆                ┆               ┆      ┆               ┆               │
# │ Yuba    ┆ Cities         ┆ null           ┆ null          ┆ 2018 ┆ city          ┆ null          │
# │ Yuba    ┆ Marysville     ┆ 930            ┆ 1857          ┆ 2018 ┆ city          ┆ null          │
# │ Yuba    ┆ Wheatland      ┆ 250            ┆ 591           ┆ 2018 ┆ city          ┆ null          │
# │ Yuba    ┆ Unincorporated ┆ 4787           ┆ 10397         ┆ 2018 ┆ city          ┆ null          │
# │         ┆ area of Yuba   ┆                ┆               ┆      ┆               ┆               │
# │         ┆ Co…            ┆                ┆               ┆      ┆               ┆               │
# └─────────┴────────────────┴────────────────┴───────────────┴──────┴───────────────┴───────────────┘

# %%
# Get the original number of rows for data validation
original_row_count = df.shape[0]

original_geo_type_count = df.select("geo_type").unique().count()

original_sub_county_count = df.select("sub_county").unique().count()

# Drop rows where 'geo_type' is null or 'city_end', and where 'sub_county' is 'Cities'
df_cleaned = (df
    .drop_nulls(subset=['geo_type'])
    .filter((pl.col('geo_type') != 'city_end') & (pl.col('sub_county') != 'Cities'))
)

# Get the new number of rows
new_row_count = df_cleaned.shape[0]

new_geo_type_count = df_cleaned.select("geo_type").unique().count()

new_sub_county_count = df_cleaned.select("sub_county").unique().count()

# Calculate the number of dropped rows
dropped_row_count = original_row_count - new_row_count
dropped_geo_type_count = original_geo_type_count - new_geo_type_count
dropped_sub_county_count = original_sub_county_count - new_sub_county_count

# Create a DataFrame to show the results
result_df = pl.DataFrame({
    'Original Rows': [original_row_count],
    'Rows After Cleaning': [new_row_count],
    'Rows Dropped': [dropped_row_count],
    'Geo Types After Cleaning': [new_geo_type_count],
    'Geo Types Dropped': [dropped_geo_type_count],
    'Sub Counties After Cleaning': [new_sub_county_count],
    'Sub Counties Dropped': [dropped_sub_county_count]
})

# Calculate and display the percentage of rows dropped
percentage_dropped = (dropped_row_count / original_row_count) * 100
print(f"Percentage of rows dropped: {percentage_dropped:.2f}%")


# Display the result
result_df
# Out:
# Percentage of rows dropped: 21.91%
# shape: (1, 7)
# ┌──────────┬───────────────┬─────────┬───────────────┬───────────────┬──────────────┬──────────────┐
# │ Original ┆ Rows After    ┆ Rows    ┆ Geo Types     ┆ Geo Types     ┆ Sub Counties ┆ Sub Counties │
# │ Rows     ┆ Cleaning      ┆ Dropped ┆ After         ┆ Dropped       ┆ After        ┆ Dropped      │
# │ ---      ┆ ---           ┆ ---     ┆ Cleaning      ┆ ---           ┆ Cleaning     ┆ ---          │
# │ i64      ┆ i64           ┆ i64     ┆ ---           ┆ object        ┆ ---          ┆ object       │
# │          ┆               ┆         ┆ object        ┆               ┆ object       ┆              │
# ╞══════════╪═══════════════╪═════════╪═══════════════╪═══════════════╪══════════════╪══════════════╡
# │ 4560     ┆ 3561          ┆ 999     ┆ shape: (1, 1) ┆ shape: (1, 1) ┆ shape: (1,   ┆ shape: (1,   │
# │          ┆               ┆         ┆ ┌──────────┐  ┆ ┌──────────┐  ┆ 1)           ┆ 1)           │
# │          ┆               ┆         ┆ │ g…          ┆ │ g…          ┆ ┌─────────── ┆ ┌─────────── │
# │          ┆               ┆         ┆               ┆               ┆ ─┐           ┆ ─┐           │
# │          ┆               ┆         ┆               ┆               ┆ │…           ┆ │…           │
# └──────────┴───────────────┴─────────┴───────────────┴───────────────┴──────────────┴──────────────┘

# %%
df_cleaned
# Out:
# shape: (3_561, 7)
# ┌─────────┬───────────────────────┬────────┬────────┬──────┬───────────────────────┬───────────────┐
# │ county  ┆ sub_county            ┆ yes    ┆ no     ┆ year ┆ geo_type              ┆ sub_county_id │
# │ ---     ┆ ---                   ┆ ---    ┆ ---    ┆ ---  ┆ ---                   ┆ ---           │
# │ str     ┆ str                   ┆ str    ┆ str    ┆ i32  ┆ str                   ┆ str           │
# ╞═════════╪═══════════════════════╪════════╪════════╪══════╪═══════════════════════╪═══════════════╡
# │ Alameda ┆ County Supervisorial  ┆ 31161  ┆ 65845  ┆ 2022 ┆ county_supervisorial_ ┆ 1             │
# │         ┆ 1                     ┆        ┆        ┆      ┆ district              ┆               │
# │ Alameda ┆ County Supervisorial  ┆ 28778  ┆ 44258  ┆ 2022 ┆ county_supervisorial_ ┆ 2             │
# │         ┆ 2                     ┆        ┆        ┆      ┆ district              ┆               │
# │ Alameda ┆ County Supervisorial  ┆ 34338  ┆ 48590  ┆ 2022 ┆ county_supervisorial_ ┆ 3             │
# │         ┆ 3                     ┆        ┆        ┆      ┆ district              ┆               │
# │ Alameda ┆ County Supervisorial  ┆ 33897  ┆ 60759  ┆ 2022 ┆ county_supervisorial_ ┆ 4             │
# │         ┆ 4                     ┆        ┆        ┆      ┆ district              ┆               │
# │ Alameda ┆ County Supervisorial  ┆ 54523  ┆ 71294  ┆ 2022 ┆ county_supervisorial_ ┆ 5             │
# │         ┆ 5                     ┆        ┆        ┆      ┆ district              ┆               │
# │ Alameda ┆ US Congressional 10   ┆ 4465   ┆ 7055   ┆ 2022 ┆ federal_congressional ┆ 10            │
# │         ┆                       ┆        ┆        ┆      ┆ _district             ┆               │
# │ Alameda ┆ US Congressional 12   ┆ 100680 ┆ 135563 ┆ 2022 ┆ federal_congressional ┆ 12            │
# │         ┆                       ┆        ┆        ┆      ┆ _district             ┆               │
# │ Alameda ┆ US Congressional 14   ┆ 67996  ┆ 131310 ┆ 2022 ┆ federal_congressional ┆ 14            │
# │         ┆                       ┆        ┆        ┆      ┆ _district             ┆               │
# │ Alameda ┆ US Congressional 17   ┆ 9556   ┆ 16818  ┆ 2022 ┆ federal_congressional ┆ 17            │
# │         ┆                       ┆        ┆        ┆      ┆ _district             ┆               │
# │ Alameda ┆ State Senate 5        ┆ 23169  ┆ 56283  ┆ 2022 ┆ state_senate_district ┆ 5             │
# │ Alameda ┆ State Senate 7        ┆ 93718  ┆ 124902 ┆ 2022 ┆ state_senate_district ┆ 7             │
# │ Alameda ┆ State Senate 9        ┆ 20989  ┆ 36471  ┆ 2022 ┆ state_senate_district ┆ 9             │
# │ Alameda ┆ State Senate 10       ┆ 44821  ┆ 73090  ┆ 2022 ┆ state_senate_district ┆ 10            │
# │ Alameda ┆ State Assembly 14     ┆ 32876  ┆ 50457  ┆ 2022 ┆ state_assembly_distri ┆ 14            │
# │         ┆                       ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Alameda ┆ State Assembly 16     ┆ 18544  ┆ 45874  ┆ 2022 ┆ state_assembly_distri ┆ 16            │
# │         ┆                       ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Alameda ┆ State Assembly 18     ┆ 60844  ┆ 74454  ┆ 2022 ┆ state_assembly_distri ┆ 18            │
# │         ┆                       ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Alameda ┆ State Assembly 20     ┆ 46517  ┆ 77807  ┆ 2022 ┆ state_assembly_distri ┆ 20            │
# │         ┆                       ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Alameda ┆ State Assembly 24     ┆ 23916  ┆ 42154  ┆ 2022 ┆ state_assembly_distri ┆ 24            │
# │         ┆                       ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Alameda ┆ State Board of        ┆ 182697 ┆ 290746 ┆ 2022 ┆ state_assembly_distri ┆ 2             │
# │         ┆ Equalization 2        ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Alameda ┆ Alameda               ┆ 10709  ┆ 18797  ┆ 2022 ┆ city                  ┆ null          │
# │ Alameda ┆ Albany                ┆ 3194   ┆ 4501   ┆ 2022 ┆ city                  ┆ null          │
# │ Alameda ┆ Berkeley              ┆ 18604  ┆ 25632  ┆ 2022 ┆ city                  ┆ null          │
# │ Alameda ┆ Dublin                ┆ 6134   ┆ 10881  ┆ 2022 ┆ city                  ┆ null          │
# │ Alameda ┆ Emeryville            ┆ 1645   ┆ 1967   ┆ 2022 ┆ city                  ┆ null          │
# │ Alameda ┆ Fremont               ┆ 19741  ┆ 34846  ┆ 2022 ┆ city                  ┆ null          │
# │ …       ┆ …                     ┆ …      ┆ …      ┆ …    ┆ …                     ┆ …             │
# │ Ventura ┆ Port Hueneme          ┆ 2470   ┆ 3246   ┆ 2018 ┆ city                  ┆ null          │
# │ Ventura ┆ San Buenaventura      ┆ 18348  ┆ 26855  ┆ 2018 ┆ city                  ┆ null          │
# │ Ventura ┆ Santa Paula           ┆ 2822   ┆ 4557   ┆ 2018 ┆ city                  ┆ null          │
# │ Ventura ┆ Simi Valley           ┆ 18093  ┆ 32714  ┆ 2018 ┆ city                  ┆ null          │
# │ Ventura ┆ Thousand Oaks         ┆ 20191  ┆ 37162  ┆ 2018 ┆ city                  ┆ null          │
# │ Ventura ┆ Unincorporated area   ┆ 14127  ┆ 23463  ┆ 2018 ┆ city                  ┆ null          │
# │         ┆ of Ventura…           ┆        ┆        ┆      ┆                       ┆               │
# │ Yolo    ┆ Congressional         ┆ 23223  ┆ 32529  ┆ 2018 ┆ federal_congressional ┆ 3             │
# │         ┆ District 3            ┆        ┆        ┆      ┆ _district             ┆               │
# │ Yolo    ┆ Congressional         ┆ 6238   ┆ 9353   ┆ 2018 ┆ federal_congressional ┆ 6             │
# │         ┆ District 6            ┆        ┆        ┆      ┆ _district             ┆               │
# │ Yolo    ┆ State Senate District ┆ 23223  ┆ 32529  ┆ 2018 ┆ state_senate_district ┆ 3             │
# │         ┆ 3                     ┆        ┆        ┆      ┆                       ┆               │
# │ Yolo    ┆ State Senate District ┆ 6238   ┆ 9353   ┆ 2018 ┆ state_senate_district ┆ 6             │
# │         ┆ 6                     ┆        ┆        ┆      ┆                       ┆               │
# │ Yolo    ┆ State Assembly        ┆ 23223  ┆ 32529  ┆ 2018 ┆ state_assembly_distri ┆ 4             │
# │         ┆ District 4            ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Yolo    ┆ State Assembly        ┆ 6238   ┆ 9353   ┆ 2018 ┆ state_assembly_distri ┆ 7             │
# │         ┆ District 7            ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Yolo    ┆ Board of Equalization ┆ 29461  ┆ 41882  ┆ 2018 ┆ state_assembly_distri ┆ 2             │
# │         ┆ District…             ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Yolo    ┆ Davis                 ┆ 12662  ┆ 14572  ┆ 2018 ┆ city                  ┆ null          │
# │ Yolo    ┆ West Sacramento       ┆ 6238   ┆ 9353   ┆ 2018 ┆ city                  ┆ null          │
# │ Yolo    ┆ Winters               ┆ 896    ┆ 1423   ┆ 2018 ┆ city                  ┆ null          │
# │ Yolo    ┆ Woodland              ┆ 6863   ┆ 11569  ┆ 2018 ┆ city                  ┆ null          │
# │ Yolo    ┆ Unincorporated area   ┆ 2802   ┆ 4965   ┆ 2018 ┆ city                  ┆ null          │
# │         ┆ of Yolo Co…           ┆        ┆        ┆      ┆                       ┆               │
# │ Yuba    ┆ Congressional         ┆ 5967   ┆ 12845  ┆ 2018 ┆ federal_congressional ┆ 3             │
# │         ┆ District 3            ┆        ┆        ┆      ┆ _district             ┆               │
# │ Yuba    ┆ State Senate District ┆ 5967   ┆ 12845  ┆ 2018 ┆ state_senate_district ┆ 4             │
# │         ┆ 4                     ┆        ┆        ┆      ┆                       ┆               │
# │ Yuba    ┆ State Assembly        ┆ 5967   ┆ 12845  ┆ 2018 ┆ state_assembly_distri ┆ 3             │
# │         ┆ District 3            ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Yuba    ┆ Board of Equalization ┆ 5967   ┆ 12845  ┆ 2018 ┆ state_assembly_distri ┆ 1             │
# │         ┆ District…             ┆        ┆        ┆      ┆ ct                    ┆               │
# │ Yuba    ┆ Marysville            ┆ 930    ┆ 1857   ┆ 2018 ┆ city                  ┆ null          │
# │ Yuba    ┆ Wheatland             ┆ 250    ┆ 591    ┆ 2018 ┆ city                  ┆ null          │
# │ Yuba    ┆ Unincorporated area   ┆ 4787   ┆ 10397  ┆ 2018 ┆ city                  ┆ null          │
# │         ┆ of Yuba Co…           ┆        ┆        ┆      ┆                       ┆               │
# └─────────┴───────────────────────┴────────┴────────┴──────┴───────────────────────┴───────────────┘

# %%
# Unpivoting the data so it's in "tidy" format
# Tidy essentially means  each variable has its own column, and each observation has its own row
# This makes it easier to merge, analyze, model, and visualize data
# Also in this step we rename columns to be more informative

df_cleaned = (
    df_cleaned
    .unpivot(
        index = ['county', 'sub_county', 'geo_type', 'sub_county_id', 'year'],
        on = ['yes', 'no'],
        value_name = "vote_count"
    )
    .with_columns(
        pl.col("variable")
    .alias("vote_type"))
    .with_columns(
        pl.col("sub_county_id")
        .alias("district_id"))
    .drop(pl.col(["variable", "sub_county_id"]))
)

# %%
# Reordering the columns for clarity/readability

df_cleaned = df_cleaned.select(["year", "county", "sub_county", "district_id", "geo_type", "vote_type", "vote_count"])

df_cleaned
# Out:
# shape: (7_122, 7)
# ┌──────┬─────────┬─────────────────────┬─────────────┬────────────────────┬───────────┬────────────┐
# │ year ┆ county  ┆ sub_county          ┆ district_id ┆ geo_type           ┆ vote_type ┆ vote_count │
# │ ---  ┆ ---     ┆ ---                 ┆ ---         ┆ ---                ┆ ---       ┆ ---        │
# │ i32  ┆ str     ┆ str                 ┆ str         ┆ str                ┆ str       ┆ str        │
# ╞══════╪═════════╪═════════════════════╪═════════════╪════════════════════╪═══════════╪════════════╡
# │ 2022 ┆ Alameda ┆ County              ┆ 1           ┆ county_supervisori ┆ yes       ┆ 31161      │
# │      ┆         ┆ Supervisorial 1     ┆             ┆ al_district        ┆           ┆            │
# │ 2022 ┆ Alameda ┆ County              ┆ 2           ┆ county_supervisori ┆ yes       ┆ 28778      │
# │      ┆         ┆ Supervisorial 2     ┆             ┆ al_district        ┆           ┆            │
# │ 2022 ┆ Alameda ┆ County              ┆ 3           ┆ county_supervisori ┆ yes       ┆ 34338      │
# │      ┆         ┆ Supervisorial 3     ┆             ┆ al_district        ┆           ┆            │
# │ 2022 ┆ Alameda ┆ County              ┆ 4           ┆ county_supervisori ┆ yes       ┆ 33897      │
# │      ┆         ┆ Supervisorial 4     ┆             ┆ al_district        ┆           ┆            │
# │ 2022 ┆ Alameda ┆ County              ┆ 5           ┆ county_supervisori ┆ yes       ┆ 54523      │
# │      ┆         ┆ Supervisorial 5     ┆             ┆ al_district        ┆           ┆            │
# │ 2022 ┆ Alameda ┆ US Congressional 10 ┆ 10          ┆ federal_congressio ┆ yes       ┆ 4465       │
# │      ┆         ┆                     ┆             ┆ nal_district       ┆           ┆            │
# │ 2022 ┆ Alameda ┆ US Congressional 12 ┆ 12          ┆ federal_congressio ┆ yes       ┆ 100680     │
# │      ┆         ┆                     ┆             ┆ nal_district       ┆           ┆            │
# │ 2022 ┆ Alameda ┆ US Congressional 14 ┆ 14          ┆ federal_congressio ┆ yes       ┆ 67996      │
# │      ┆         ┆                     ┆             ┆ nal_district       ┆           ┆            │
# │ 2022 ┆ Alameda ┆ US Congressional 17 ┆ 17          ┆ federal_congressio ┆ yes       ┆ 9556       │
# │      ┆         ┆                     ┆             ┆ nal_district       ┆           ┆            │
# │ 2022 ┆ Alameda ┆ State Senate 5      ┆ 5           ┆ state_senate_distr ┆ yes       ┆ 23169      │
# │      ┆         ┆                     ┆             ┆ ict                ┆           ┆            │
# │ 2022 ┆ Alameda ┆ State Senate 7      ┆ 7           ┆ state_senate_distr ┆ yes       ┆ 93718      │
# │      ┆         ┆                     ┆             ┆ ict                ┆           ┆            │
# │ 2022 ┆ Alameda ┆ State Senate 9      ┆ 9           ┆ state_senate_distr ┆ yes       ┆ 20989      │
# │      ┆         ┆                     ┆             ┆ ict                ┆           ┆            │
# │ 2022 ┆ Alameda ┆ State Senate 10     ┆ 10          ┆ state_senate_distr ┆ yes       ┆ 44821      │
# │      ┆         ┆                     ┆             ┆ ict                ┆           ┆            │
# │ 2022 ┆ Alameda ┆ State Assembly 14   ┆ 14          ┆ state_assembly_dis ┆ yes       ┆ 32876      │
# │      ┆         ┆                     ┆             ┆ trict              ┆           ┆            │
# │ 2022 ┆ Alameda ┆ State Assembly 16   ┆ 16          ┆ state_assembly_dis ┆ yes       ┆ 18544      │
# │      ┆         ┆                     ┆             ┆ trict              ┆           ┆            │
# │ 2022 ┆ Alameda ┆ State Assembly 18   ┆ 18          ┆ state_assembly_dis ┆ yes       ┆ 60844      │
# │      ┆         ┆                     ┆             ┆ trict              ┆           ┆            │
# │ 2022 ┆ Alameda ┆ State Assembly 20   ┆ 20          ┆ state_assembly_dis ┆ yes       ┆ 46517      │
# │      ┆         ┆                     ┆             ┆ trict              ┆           ┆            │
# │ 2022 ┆ Alameda ┆ State Assembly 24   ┆ 24          ┆ state_assembly_dis ┆ yes       ┆ 23916      │
# │      ┆         ┆                     ┆             ┆ trict              ┆           ┆            │
# │ 2022 ┆ Alameda ┆ State Board of      ┆ 2           ┆ state_assembly_dis ┆ yes       ┆ 182697     │
# │      ┆         ┆ Equalization 2      ┆             ┆ trict              ┆           ┆            │
# │ 2022 ┆ Alameda ┆ Alameda             ┆ null        ┆ city               ┆ yes       ┆ 10709      │
# │ 2022 ┆ Alameda ┆ Albany              ┆ null        ┆ city               ┆ yes       ┆ 3194       │
# │ 2022 ┆ Alameda ┆ Berkeley            ┆ null        ┆ city               ┆ yes       ┆ 18604      │
# │ 2022 ┆ Alameda ┆ Dublin              ┆ null        ┆ city               ┆ yes       ┆ 6134       │
# │ 2022 ┆ Alameda ┆ Emeryville          ┆ null        ┆ city               ┆ yes       ┆ 1645       │
# │ 2022 ┆ Alameda ┆ Fremont             ┆ null        ┆ city               ┆ yes       ┆ 19741      │
# │ …    ┆ …       ┆ …                   ┆ …           ┆ …                  ┆ …         ┆ …          │
# │ 2018 ┆ Ventura ┆ Port Hueneme        ┆ null        ┆ city               ┆ no        ┆ 3246       │
# │ 2018 ┆ Ventura ┆ San Buenaventura    ┆ null        ┆ city               ┆ no        ┆ 26855      │
# │ 2018 ┆ Ventura ┆ Santa Paula         ┆ null        ┆ city               ┆ no        ┆ 4557       │
# │ 2018 ┆ Ventura ┆ Simi Valley         ┆ null        ┆ city               ┆ no        ┆ 32714      │
# │ 2018 ┆ Ventura ┆ Thousand Oaks       ┆ null        ┆ city               ┆ no        ┆ 37162      │
# │ 2018 ┆ Ventura ┆ Unincorporated area ┆ null        ┆ city               ┆ no        ┆ 23463      │
# │      ┆         ┆ of Ventura…         ┆             ┆                    ┆           ┆            │
# │ 2018 ┆ Yolo    ┆ Congressional       ┆ 3           ┆ federal_congressio ┆ no        ┆ 32529      │
# │      ┆         ┆ District 3          ┆             ┆ nal_district       ┆           ┆            │
# │ 2018 ┆ Yolo    ┆ Congressional       ┆ 6           ┆ federal_congressio ┆ no        ┆ 9353       │
# │      ┆         ┆ District 6          ┆             ┆ nal_district       ┆           ┆            │
# │ 2018 ┆ Yolo    ┆ State Senate        ┆ 3           ┆ state_senate_distr ┆ no        ┆ 32529      │
# │      ┆         ┆ District 3          ┆             ┆ ict                ┆           ┆            │
# │ 2018 ┆ Yolo    ┆ State Senate        ┆ 6           ┆ state_senate_distr ┆ no        ┆ 9353       │
# │      ┆         ┆ District 6          ┆             ┆ ict                ┆           ┆            │
# │ 2018 ┆ Yolo    ┆ State Assembly      ┆ 4           ┆ state_assembly_dis ┆ no        ┆ 32529      │
# │      ┆         ┆ District 4          ┆             ┆ trict              ┆           ┆            │
# │ 2018 ┆ Yolo    ┆ State Assembly      ┆ 7           ┆ state_assembly_dis ┆ no        ┆ 9353       │
# │      ┆         ┆ District 7          ┆             ┆ trict              ┆           ┆            │
# │ 2018 ┆ Yolo    ┆ Board of            ┆ 2           ┆ state_assembly_dis ┆ no        ┆ 41882      │
# │      ┆         ┆ Equalization        ┆             ┆ trict              ┆           ┆            │
# │      ┆         ┆ District…           ┆             ┆                    ┆           ┆            │
# │ 2018 ┆ Yolo    ┆ Davis               ┆ null        ┆ city               ┆ no        ┆ 14572      │
# │ 2018 ┆ Yolo    ┆ West Sacramento     ┆ null        ┆ city               ┆ no        ┆ 9353       │
# │ 2018 ┆ Yolo    ┆ Winters             ┆ null        ┆ city               ┆ no        ┆ 1423       │
# │ 2018 ┆ Yolo    ┆ Woodland            ┆ null        ┆ city               ┆ no        ┆ 11569      │
# │ 2018 ┆ Yolo    ┆ Unincorporated area ┆ null        ┆ city               ┆ no        ┆ 4965       │
# │      ┆         ┆ of Yolo Co…         ┆             ┆                    ┆           ┆            │
# │ 2018 ┆ Yuba    ┆ Congressional       ┆ 3           ┆ federal_congressio ┆ no        ┆ 12845      │
# │      ┆         ┆ District 3          ┆             ┆ nal_district       ┆           ┆            │
# │ 2018 ┆ Yuba    ┆ State Senate        ┆ 4           ┆ state_senate_distr ┆ no        ┆ 12845      │
# │      ┆         ┆ District 4          ┆             ┆ ict                ┆           ┆            │
# │ 2018 ┆ Yuba    ┆ State Assembly      ┆ 3           ┆ state_assembly_dis ┆ no        ┆ 12845      │
# │      ┆         ┆ District 3          ┆             ┆ trict              ┆           ┆            │
# │ 2018 ┆ Yuba    ┆ Board of            ┆ 1           ┆ state_assembly_dis ┆ no        ┆ 12845      │
# │      ┆         ┆ Equalization        ┆             ┆ trict              ┆           ┆            │
# │      ┆         ┆ District…           ┆             ┆                    ┆           ┆            │
# │ 2018 ┆ Yuba    ┆ Marysville          ┆ null        ┆ city               ┆ no        ┆ 1857       │
# │ 2018 ┆ Yuba    ┆ Wheatland           ┆ null        ┆ city               ┆ no        ┆ 591        │
# │ 2018 ┆ Yuba    ┆ Unincorporated area ┆ null        ┆ city               ┆ no        ┆ 10397      │
# │      ┆         ┆ of Yuba Co…         ┆             ┆                    ┆           ┆            │
# └──────┴─────────┴─────────────────────┴─────────────┴────────────────────┴───────────┴────────────┘

# %%
# Generating a timestamp for the files
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Defining output paths without timestamp to replace the prior version
output_path = '../../../003_data/001_raw-data/2018-2022_ballot-measure_sub-county_data.parquet'

# Function to save Polars DataFrame as Parquet with metadata
def save_polars_parquet_with_metadata(df, output_path, description):
    try:
        # Convert Polars DataFrame to Arrow Table
        arrow_table = df.to_arrow()

        # Get existing metadata
        metadata = arrow_table.schema.metadata if arrow_table.schema.metadata else {}

        # Update metadata
        metadata.update({
            b'created_at': str(datetime.now()).encode('utf-8'),
            b'description': description.encode('utf-8'),
            b'version': b'1.0',
            b'cleaning_steps': b'''
                1. Downloaded Excel files from California Secretary of State website for 2018, 2020, and 2022 elections.
                2. Processed each Excel file:
                   a. Selected first two columns (county and sub_county).
                   b. Identified and selected columns related to kidney/dialysis propositions and their corresponding No vote columns.
                   c. Renamed columns: first two as 'county' and 'sub_county', proposition column as 'yes', following column as 'no'.
                   d. Added 'year' column to each dataset.
                3. Combined data from all years into a single DataFrame.
                4. Unnested sub-county data into geo_type and sub_county_id.
                5. Reshaped data:
                   a. Unpivoted 'yes' and 'no' columns.
                6. Renamed columns to make them easier to interpret :
                   a. yes/no vote column as 'vote_type'
                   b. sub_county_id as 'district_id'
                7. Reordered columns for clarity/readability
            '''
        })

        # Creating a new Arrow Table with updated metadata
        updated_table = arrow_table.replace_schema_metadata(metadata)

        # Writing the updated table to a Parquet file with Snappy compression to reduce file size
        pq.write_table(updated_table, output_path, compression='snappy')

        print(f"Data saved to {output_path}")
    except Exception as e:
        print(f"Error saving data: {e}")
        raise

# Saving the merged dataframes as parquet files
save_polars_parquet_with_metadata(df_cleaned, output_path, "Merged 2018-2022 ballot measure sub-county data")
# Out:
# Data saved to ../../../003_data/001_raw-data/2018-2022_ballot-measure_sub-county_data.parquet
