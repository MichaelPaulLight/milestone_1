# %%
import pandas as pd

# %%
city_df = pd.read_parquet("../../../003_data/01_raw-data/2017-2024_national_cms_dialysis-facility_cahps-data.parquet")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 city_df = pd.read_parquet("../../../003_data/01_raw-data/2017-2024_national_cms_dialysis-facility_cahps-data.parquet")
#
# File c:\Users\Iris.Lin\AppData\Local\anaconda3\Lib\site-packages\pandas\io\parquet.py:670, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     667     use_nullable_dtypes = False
#     668 check_dtype_backend(dtype_backend)
# --> 670 return impl.read(
#     671     path,
#     672     columns=columns,
#     673     filters=filters,
#     674     storage_options=storage_options,
#     675     use_nullable_dtypes=use_nullable_dtypes,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     **kwargs,
#     679 )
#
# ...

# %%
#city_vote_df = city_df.dropna(subset=['vote_count']).copy()

# %%
city_df.head()
# Out:
#    year         county           city provider_number  ASSEMBLY_DIST  \
# 0  2024  santa barbara  santa barbara           52513           37.0
# 1  2024  santa barbara  santa barbara           52513           37.0
# 2  2024  santa barbara  santa barbara           52513           37.0
# 3  2024  santa barbara  santa barbara           52513           37.0
# 4  2024  santa barbara  santa barbara           52513           37.0
#
#     CENS_TRACT   LONGITUDE   LATITUDE profit_or_nonprofit  \
# 0  06083000102 -119.758390  34.443550              profit
# 1  06083000102 -119.758390  34.443550              profit
# 2  06083000102 -119.758045  34.443562              profit
# 3  06083000102 -119.758045  34.443562              profit
# 4  06083000102 -119.758045  34.443562              profit
#
#   std_chain_organization  ...  \
# 0   freseniusmedicalcare  ...
# 1   freseniusmedicalcare  ...
# 2   freseniusmedicalcare  ...
# 3   freseniusmedicalcare  ...
# 4   freseniusmedicalcare  ...
#
# ...
